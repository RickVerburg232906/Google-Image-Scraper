# %% [markdown]
# # Image scraper
#
# ## Step 1: Create the Conda Environment
# Open your terminal (on macOS/Linux) or Anaconda Prompt (on Windows) and run the following command to create a new Conda environment named image_scraper with Python 3.11:
#
# ```console
# conda create --name image_scraper python=3.11
# ```
#
# ## Step 2: Activate the Environment
#
# Activate the newly created environment using:
#
# ```console
# conda activate image_scraper
# ```
#
# ## Step 3: Install Required Packages
#
# Install the necessary libraries for web scraping (Selenium and Requests), WebDriver Manager for Selenium driver management, and Jupyter to run and manage your notebooks. Here's the command sequence:
#
# ```console
# conda install selenium requests jupyter -c conda-forge
# pip install webdriver-manager
# ```
#
# Using -c conda-forge specifies that Conda should install these packages from the Conda-Forge repository, which often has more up-to-date packages than the default channel.
#
# ## Step 4: Install Jupyter Kernel
# To make your image_scraper environment available as a kernel in Jupyter Notebooks, install ipykernel and add it as a kernel:
#
# ```console
# conda install ipykernel -c conda-forge
# python -m ipykernel install --user --name=image_scraper --display-name="Python 3.11 (image_scraper)"
# ```
#
# This command adds the image_scraper environment as a kernel option in Jupyter, allowing you to select it when working on notebooks related to your image scraping project.
#
# ## Step 5: Run Jupyter Notebook
#
# See code below for the image scraper:

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import requests
import os
import time

def download_image(image_url, directory, index):
    """
    Downloads an image from a given URL into a specified directory.
    """
    try:
        response = requests.get(image_url)
        if response.status_code == 200:
            file_path = os.path.join(directory, f'image_{index}.jpg')
            with open(file_path, 'wb') as file:
                file.write(response.content)
            print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Error downloading {image_url}: {e}")

def scrape_images(search_term, limit):
    """
    Scrapes images from DuckDuckGo based on a search term up to a specified limit.
    """
    # Initialize the Chrome driver
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)

    # Go to DuckDuckGo's image search page
    driver.get(f"https://duckduckgo.com/?q={search_term}&iax=images&ia=images")
    time.sleep(3)  # Allow time for the page to load

    # Scroll the page to ensure that images are loaded
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)  # Wait for new images to load
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    # Find image elements on the page
    images = driver.find_elements(By.CSS_SELECTOR, "img.tile--img__img.js-lazyload")
    images = images[:limit]  # Limit the number of images to download

    # Create a directory for the downloaded images
    directory = f"downloaded_images_{search_term.replace(' ', '_')}"
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Download the images
    for index, image in enumerate(images):
        image_url = image.get_attribute('src')
        if image_url:
            download_image(image_url, directory, index)

    driver.quit()
    print(f"Finished downloading images to {directory}.")

# Example usage
search_term = "Parallel port "  # Specify the search term here
limit = 105  # Specify the maximum number of images to download

scrape_images(search_term, limit)
# Out:
# Downloaded downloaded_images_Parallel_port_\image_0.jpg
# Downloaded downloaded_images_Parallel_port_\image_1.jpg
# Downloaded downloaded_images_Parallel_port_\image_3.jpg
# Downloaded downloaded_images_Parallel_port_\image_4.jpg
# Downloaded downloaded_images_Parallel_port_\image_5.jpg
# Downloaded downloaded_images_Parallel_port_\image_6.jpg
# Downloaded downloaded_images_Parallel_port_\image_7.jpg
# Downloaded downloaded_images_Parallel_port_\image_8.jpg
# Downloaded downloaded_images_Parallel_port_\image_9.jpg
# Downloaded downloaded_images_Parallel_port_\image_10.jpg
# Downloaded downloaded_images_Parallel_port_\image_11.jpg
# Downloaded downloaded_images_Parallel_port_\image_12.jpg
# Downloaded downloaded_images_Parallel_port_\image_13.jpg
# Downloaded downloaded_images_Parallel_port_\image_14.jpg
# Downloaded downloaded_images_Parallel_port_\image_15.jpg
# Downloaded downloaded_images_Parallel_port_\image_16.jpg
# Downloaded downloaded_images_Parallel_port_\image_17.jpg
# Downloaded downloaded_images_Parallel_port_\image_18.jpg
# Downloaded downloaded_images_Parallel_port_\image_19.jpg
# Downloaded downloaded_images_Parallel_port_\image_20.jpg
# Downloaded downloaded_images_Parallel_port_\image_21.jpg
# Downloaded downloaded_images_Parallel_port_\image_22.jpg
# Downloaded downloaded_images_Parallel_port_\image_23.jpg
# Downloaded downloaded_images_Parallel_port_\image_24.jpg
# Downloaded downloaded_images_Parallel_port_\image_25.jpg
# Downloaded downloaded_images_Parallel_port_\image_26.jpg
# Downloaded downloaded_images_Parallel_port_\image_27.jpg
# Downloaded downloaded_images_Parallel_port_\image_28.jpg
# Downloaded downloaded_images_Parallel_port_\image_29.jpg
# Downloaded downloaded_images_Parallel_port_\image_30.jpg
# Downloaded downloaded_images_Parallel_port_\image_31.jpg
# Downloaded downloaded_images_Parallel_port_\image_32.jpg
# Downloaded downloaded_images_Parallel_port_\image_33.jpg
# Downloaded downloaded_images_Parallel_port_\image_34.jpg
# Downloaded downloaded_images_Parallel_port_\image_35.jpg
# Downloaded downloaded_images_Parallel_port_\image_36.jpg
# Downloaded downloaded_images_Parallel_port_\image_37.jpg
# Downloaded downloaded_images_Parallel_port_\image_38.jpg
# Downloaded downloaded_images_Parallel_port_\image_39.jpg
# Downloaded downloaded_images_Parallel_port_\image_40.jpg
# Downloaded downloaded_images_Parallel_port_\image_41.jpg
# Downloaded downloaded_images_Parallel_port_\image_42.jpg
# Downloaded downloaded_images_Parallel_port_\image_43.jpg
# Downloaded downloaded_images_Parallel_port_\image_44.jpg
# Downloaded downloaded_images_Parallel_port_\image_45.jpg
# Downloaded downloaded_images_Parallel_port_\image_46.jpg
# Downloaded downloaded_images_Parallel_port_\image_47.jpg
# Downloaded downloaded_images_Parallel_port_\image_48.jpg
# Downloaded downloaded_images_Parallel_port_\image_49.jpg
# Downloaded downloaded_images_Parallel_port_\image_50.jpg
# Downloaded downloaded_images_Parallel_port_\image_51.jpg
# Downloaded downloaded_images_Parallel_port_\image_52.jpg
# Downloaded downloaded_images_Parallel_port_\image_53.jpg
# Downloaded downloaded_images_Parallel_port_\image_54.jpg
# Downloaded downloaded_images_Parallel_port_\image_55.jpg
# Downloaded downloaded_images_Parallel_port_\image_56.jpg
# Downloaded downloaded_images_Parallel_port_\image_57.jpg
# Downloaded downloaded_images_Parallel_port_\image_58.jpg
# Downloaded downloaded_images_Parallel_port_\image_59.jpg
# Downloaded downloaded_images_Parallel_port_\image_60.jpg
# Downloaded downloaded_images_Parallel_port_\image_61.jpg
# Downloaded downloaded_images_Parallel_port_\image_62.jpg
# Downloaded downloaded_images_Parallel_port_\image_63.jpg
# Downloaded downloaded_images_Parallel_port_\image_64.jpg
# Downloaded downloaded_images_Parallel_port_\image_65.jpg
# Downloaded downloaded_images_Parallel_port_\image_66.jpg
# Downloaded downloaded_images_Parallel_port_\image_67.jpg
# Downloaded downloaded_images_Parallel_port_\image_68.jpg
# Downloaded downloaded_images_Parallel_port_\image_69.jpg
# Downloaded downloaded_images_Parallel_port_\image_70.jpg
# Downloaded downloaded_images_Parallel_port_\image_71.jpg
# Downloaded downloaded_images_Parallel_port_\image_72.jpg
# Downloaded downloaded_images_Parallel_port_\image_73.jpg
# Downloaded downloaded_images_Parallel_port_\image_74.jpg
# Downloaded downloaded_images_Parallel_port_\image_75.jpg
# Downloaded downloaded_images_Parallel_port_\image_76.jpg
# Downloaded downloaded_images_Parallel_port_\image_77.jpg
# Downloaded downloaded_images_Parallel_port_\image_78.jpg
# Downloaded downloaded_images_Parallel_port_\image_79.jpg
# Downloaded downloaded_images_Parallel_port_\image_80.jpg
# Downloaded downloaded_images_Parallel_port_\image_81.jpg
# Downloaded downloaded_images_Parallel_port_\image_82.jpg
# Downloaded downloaded_images_Parallel_port_\image_83.jpg
# Downloaded downloaded_images_Parallel_port_\image_84.jpg
# Downloaded downloaded_images_Parallel_port_\image_85.jpg
# Downloaded downloaded_images_Parallel_port_\image_86.jpg
# Downloaded downloaded_images_Parallel_port_\image_87.jpg
# Downloaded downloaded_images_Parallel_port_\image_88.jpg
# Downloaded downloaded_images_Parallel_port_\image_89.jpg
# Downloaded downloaded_images_Parallel_port_\image_90.jpg
# Downloaded downloaded_images_Parallel_port_\image_91.jpg
# Downloaded downloaded_images_Parallel_port_\image_92.jpg
# Downloaded downloaded_images_Parallel_port_\image_93.jpg
# Downloaded downloaded_images_Parallel_port_\image_94.jpg
# Downloaded downloaded_images_Parallel_port_\image_95.jpg
# Downloaded downloaded_images_Parallel_port_\image_96.jpg
# Downloaded downloaded_images_Parallel_port_\image_97.jpg
# Downloaded downloaded_images_Parallel_port_\image_98.jpg
# Downloaded downloaded_images_Parallel_port_\image_99.jpg
# Downloaded downloaded_images_Parallel_port_\image_100.jpg
# Downloaded downloaded_images_Parallel_port_\image_101.jpg
# Downloaded downloaded_images_Parallel_port_\image_102.jpg
# Downloaded downloaded_images_Parallel_port_\image_103.jpg
# Downloaded downloaded_images_Parallel_port_\image_104.jpg
# Finished downloading images to downloaded_images_Parallel_port_.

# %% [markdown]
# ## Step 6: Deactivating the Environment
#
# Once you're done working in the image_scraper environment, you can deactivate it and return to your base environment by running:
#
# ```console
# conda deactivate
# ```
#
# ## Important Considerations
#
# - This script is for educational purposes. Always respect the website's terms of service and copyright laws.
# - The performance and reliability of web scraping scripts can vary based on network conditions and changes to the target website's layout and design.
